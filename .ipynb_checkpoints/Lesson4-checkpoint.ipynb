# %%
import pandas as pd
import numpy as np
import math
import time

from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

# %%
trsn_df = pd.read_excel('QVI_transaction_data.xlsx')
bhvr_df = pd.read_csv('QVI_purchase_behaviour.csv')

# %%
trsn = trsn_df.copy()

# %% [markdown]
# # Find and remove duplicates

# %%
trsn[trsn.duplicated()]
# Out:
#          DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 124845  43374        107          107024  108462        45
#
#                                      PROD_NAME  PROD_QTY  TOT_SALES
# 124845  Smiths Thinly Cut   Roast Chicken 175g         2        6.0

# %%
trsn[trsn['TXN_ID'] == 108462]
# Out:
#          DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 124843  43374        107          107024  108462        45
# 124844  43374        107          107024  108462        18
# 124845  43374        107          107024  108462        45
#
#                                      PROD_NAME  PROD_QTY  TOT_SALES
# 124843  Smiths Thinly Cut   Roast Chicken 175g         2        6.0
# 124844          Cheetos Chs & Bacon Balls 190g         2        6.6
# 124845  Smiths Thinly Cut   Roast Chicken 175g         2        6.0

# %%
to_remove = list(trsn[trsn.duplicated()].index)
for i in to_remove:
    trsn = trsn.drop(i)

trsn = trsn.reset_index(drop=True)

# %% [markdown]
# # Show number of transactions for each store

# %%
trsn.groupby('STORE_NBR').count()
# Out:
#            DATE  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  PROD_NAME  PROD_QTY  \
# STORE_NBR
# 1           573             573     573       573        573       573
# 2           506             506     506       506        506       506
# 3          1502            1502    1502      1502       1502      1502
# 4          1678            1678    1678      1678       1678      1678
# 5          1361            1361    1361      1361       1361      1361
# ...         ...             ...     ...       ...        ...       ...
# 268         546             546     546       546        546       546
# 269        1607            1607    1607      1607       1607      1607
# 270        1630            1630    1630      1630       1630      1630
# 271        1385            1385    1385      1385       1385      1385
# 272         563             563     563       563        563       563
#
#            TOT_SALES
# STORE_NBR
# 1                573
# 2                506
# 3               1502
# 4               1678
# 5               1361
# ...              ...
# 268              546
# 269             1607
# 270             1630
# 271             1385
# 272              563
#
# [272 rows x 7 columns]

# %% [markdown]
# # Find the total sales for each product and sort in descending order

# %%
trsn.groupby('PROD_NAME').sum()['TOT_SALES'].sort_values(ascending=False)
# Out:
# PROD_NAME
# Dorito Corn Chp     Supreme 380g            40352.0
# Smiths Crnkle Chip  Orgnl Big Bag 380g      36367.6
# Smiths Crinkle Chips Salt & Vinegar 330g    34804.2
# Kettle Mozzarella   Basil & Pesto 175g      34457.4
# Smiths Crinkle      Original 330g           34302.6
#                                              ...
# WW Crinkle Cut      Chicken 175g             4702.2
# Sunbites Whlegrn    Crisps Frch/Onin 90g     4600.2
# WW Crinkle Cut      Original 175g            4532.2
# Woolworths Mild     Salsa 300g               4234.5
# Woolworths Medium   Salsa 300g               4050.0
# Name: TOT_SALES, Length: 114, dtype: float64

# %% [markdown]
# # Find the price/100g for all products

# %%
# Finding weight in grams using regex
import re
# https://www.w3schools.com/python/python_regex.asp
trsn['grams'] = 0
for i in range(len(trsn)):
    weight = re.findall(r'\d+', trsn.at[i, 'PROD_NAME'])[0]
    trsn.at[i, 'grams'] = int(weight)

# %%
# Finding price/100g
trsn['ppu'] = trsn['TOT_SALES'] / trsn['PROD_QTY'] # price per unit
trsn['price/100g'] = (trsn['ppu'] / trsn['grams']) * 100
trsn
# Out:
#          DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0       43390          1            1000       1         5
# 1       43599          1            1307     348        66
# 2       43605          1            1343     383        61
# 3       43329          2            2373     974        69
# 4       43330          2            2426    1038       108
# ...       ...        ...             ...     ...       ...
# 264830  43533        272          272319  270088        89
# 264831  43325        272          272358  270154        74
# 264832  43410        272          272379  270187        51
# 264833  43461        272          272379  270188        42
# 264834  43365        272          272380  270189        74
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES  grams  \
# 0         Natural Chip        Compny SeaSalt175g         2        6.0    175
# 1                       CCs Nacho Cheese    175g         3        6.3    175
# 2         Smiths Crinkle Cut  Chips Chicken 170g         2        2.9    170
# 3         Smiths Chip Thinly  S/Cream&Onion 175g         5       15.0    175
# 4       Kettle Tortilla ChpsHny&Jlpno Chili 150g         3       13.8    150
# ...                                          ...       ...        ...    ...
# 264830   Kettle Sweet Chilli And Sour Cream 175g         2       10.8    175
# 264831             Tostitos Splash Of  Lime 175g         1        4.4    175
# 264832                  Doritos Mexicana    170g         2        8.8    170
# 264833   Doritos Corn Chip Mexican Jalapeno 150g         2        7.8    150
# 264834             Tostitos Splash Of  Lime 175g         2        8.8    175
#
#          ppu  price/100g
# 0       3.00    1.714286
# 1       2.10    1.200000
# 2       1.45    0.852941
# 3       3.00    1.714286
# 4       4.60    3.066667
# ...      ...         ...
# 264830  5.40    3.085714
# 264831  4.40    2.514286
# 264832  4.40    2.588235
# 264833  3.90    2.600000
# 264834  4.40    2.514286
#
# [264835 rows x 11 columns]

# %% [markdown]
# # Give the price/100g for 'Red Rock Deli Thai Chilli&Lime 150g'

# %%
trsn[trsn['PROD_NAME'] == 'Red Rock Deli Thai  Chilli&Lime 150g']
# Out:
#          DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 28      43327         41           41486   38472        13
# 297     43288          5            5026    4524        13
# 674     43396         33           33005   29466        13
# 679     43322         33           33019   29542        13
# 855     43467         43           43147   39605        13
# ...       ...        ...             ...     ...       ...
# 264245  43431        247          247065  248974        13
# 264286  43429        248          248085  250293        13
# 264453  43401        255          255196  254766        13
# 264748  43448        268          268270  264689        13
# 264809  43364        271          271051  268507        13
#
#                                    PROD_NAME  PROD_QTY  TOT_SALES  grams  ppu  \
# 28      Red Rock Deli Thai  Chilli&Lime 150g         1        2.7    150  2.7
# 297     Red Rock Deli Thai  Chilli&Lime 150g         2        5.4    150  2.7
# 674     Red Rock Deli Thai  Chilli&Lime 150g         2        5.4    150  2.7
# 679     Red Rock Deli Thai  Chilli&Lime 150g         2        5.4    150  2.7
# 855     Red Rock Deli Thai  Chilli&Lime 150g         2        5.4    150  2.7
# ...                                      ...       ...        ...    ...  ...
# 264245  Red Rock Deli Thai  Chilli&Lime 150g         2        5.4    150  2.7
# 264286  Red Rock Deli Thai  Chilli&Lime 150g         2        5.4    150  2.7
# 264453  Red Rock Deli Thai  Chilli&Lime 150g         2        5.4    150  2.7
# 264748  Red Rock Deli Thai  Chilli&Lime 150g         1        2.7    150  2.7
# 264809  Red Rock Deli Thai  Chilli&Lime 150g         2        5.4    150  2.7
#
#         price/100g
# 28             1.8
# 297            1.8
# 674            1.8
# 679            1.8
# 855            1.8
# ...            ...
# 264245         1.8
# 264286         1.8
# 264453         1.8
# 264748         1.8
# 264809         1.8
#
# [1495 rows x 11 columns]

# %% [markdown]
# # Merge bhvr and trsn

# %%
df = pd.merge(bhvr_df, trsn, on = 'LYLTY_CARD_NBR')
df.head()
# Out:
#    LYLTY_CARD_NBR              LIFESTAGE PREMIUM_CUSTOMER   DATE  STORE_NBR  \
# 0            1000  YOUNG SINGLES/COUPLES          Premium  43390          1
# 1            1002  YOUNG SINGLES/COUPLES       Mainstream  43359          1
# 2            1003         YOUNG FAMILIES           Budget  43531          1
# 3            1003         YOUNG FAMILIES           Budget  43532          1
# 4            1004  OLDER SINGLES/COUPLES       Mainstream  43406          1
#
#    TXN_ID  PROD_NBR                               PROD_NAME  PROD_QTY  \
# 0       1         5  Natural Chip        Compny SeaSalt175g         2
# 1       2        58   Red Rock Deli Chikn&Garlic Aioli 150g         1
# 2       3        52   Grain Waves Sour    Cream&Chives 210G         1
# 3       4       106  Natural ChipCo      Hony Soy Chckn175g         1
# 4       5        96          WW Original Stacked Chips 160g         1
#
#    TOT_SALES  grams  ppu  price/100g
# 0        6.0    175  3.0    1.714286
# 1        2.7    150  2.7    1.800000
# 2        3.6    210  3.6    1.714286
# 3        3.0    175  3.0    1.714286
# 4        1.9    160  1.9    1.187500
